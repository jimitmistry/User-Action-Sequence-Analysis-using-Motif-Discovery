# %% [markdown]
# # Notes (Not Updated)
# 1. Low classification coupled with Exploring
# 2. At least one medium/high classification coupled with Learning
# 3. Promoters have a consistent pattern, they perform a social/learning activity, and always perform classification next,(lvl 1,2)
# 4. Lvl 4 promoters have higher activities involving View Discussions, wheares dropouts have a much higher propensity to explore and learn.
# 5. lvl 4 promoters engage in more social activities, and are less consistent in the pattern of classif-social/explore.
# 6. As users go throught lvl 1 through 4, they give increasing importance to discussions and less and less importance to learning. The users who do not change their approach from exploring/learning to Discusions get dropped out in later levels

# %% [markdown]
# # Promoted vs Dropout Users

# %% [markdown]
# ## Promoted 1 vs Dropout 1

# %% [markdown]
# ### Promoted 1 patterns

# %%
df1_new = get_df_set(sax_mtf_p1)
df1_new.loc[df1_new['sum_counts']>np.quantile(df1_new['sum_counts'], 0.9)].head(10)
# Out:
#                              key                           set1  user_count  \
# 0         l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)          48
# 8         e1-c-alow-e1-c-alow-e1                   (c-alow, e1)          20
# 10        e1-c-alow-e1-c-bmed-e1           (c-bmed, c-alow, e1)          15
# 18       l1-c-chigh-l1-c-bmed-l1          (l1, c-bmed, c-chigh)          16
# 26   l1-c-bmed-l1-c-chigh-break1  (l1, break1, c-bmed, c-chigh)           8
# 66        l1-c-bmed-l1-c-bmed-l1                   (l1, c-bmed)          44
# 68    l1-c-alow-l1-c-bmed-break1   (l1, c-alow, break1, c-bmed)           8
# 112       l1-c-alow-l1-c-alow-l1                   (l1, c-alow)          42
# 114   l1-c-bmed-l1-c-bmed-break1           (l1, break1, c-bmed)           7
# 143       l1-c-alow-l1-c-bmed-v1       (l1, c-alow, c-bmed, v1)           6
#
#      max_count  sum_counts
# 0          103         575
# 8          172         335
# 10          42         238
# ...

# %% [markdown]
# ### Dropout 1 patterns

# %%
df1_d = get_df_set(sax_mtf_d1)
df1_d.loc[df1_d['sum_counts']>np.quantile(df1_d['sum_counts'], 0.9)].head(10)
# Out:
#                                   key                           set1  \
# 0          c-alow-e1-c-alow-e1-c-alow                   (c-alow, e1)
# 2              l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)
# 10        c-chigh-l1-c-bmed-l1-c-bmed          (l1, c-bmed, c-chigh)
# 18             e1-c-bmed-e1-c-alow-e1           (c-bmed, e1, c-alow)
# 26             l1-c-bmed-l1-c-bmed-l1                   (l1, c-bmed)
# 28         c-alow-l1-c-bmed-v1-c-bmed       (l1, c-alow, c-bmed, v1)
# 62   c-bmed-break1-c-chigh-l1-c-chigh  (l1, break1, c-bmed, c-chigh)
# 95             l1-c-alow-l1-c-alow-l1                   (l1, c-alow)
# 97            e1-c-chigh-e1-c-bmed-e1          (c-bmed, e1, c-chigh)
# 142    c-bmed-l1-c-bmed-break1-c-bmed           (l1, break1, c-bmed)
#
#      user_count  max_count  sum_counts
# 0            43        292         566
# 2            18         42         263
# 10            9         25         149
# 18            9         19         117
# ...

# %% [markdown]
# ### Gap analysis: Activities of Promoters not done by Dropouts

# %%
df1_new.loc[df1_new['set1'].isin(set(list(df1_new['set1'].values)) - set(list(df1_d['set1'].values)))].head(10)
# Out:
#                                key                              set1  \
# 1244    c-chigh-v1-break1-l1-stop1  (break1, stop1, l1, c-chigh, v1)
# 1478    c-alow-l2-c-bmed-e1-c-alow          (c-bmed, c-alow, e1, l2)
# 1577        c-alow-s2-e1-c-alow-s2                  (s2, c-alow, e1)
# 1607        c-bmed-v1-e1-l1-break1      (l1, break1, c-bmed, e1, v1)
# 1687     e1-c-bmed-break1-l1-stop1   (break1, stop1, l1, c-bmed, e1)
# 1689    c-bmed-break1-v2-c-bmed-v1          (break1, v2, c-bmed, v1)
# 1719    c-alow-p1-c-bmed-p1-c-bmed              (p1, c-alow, c-bmed)
# 1781    p1-c-bmed-v1-c-bmed-break1          (p1, break1, c-bmed, v1)
# 1932     c-bmed-z1-break1-l1-stop1   (break1, stop1, l1, c-bmed, z1)
# 2084  p1-l1-c-chigh-break1-c-chigh         (p1, break1, c-chigh, l1)
#
#       user_count  max_count  sum_counts
# 1244           6          8          22
# 1478           2          2          16
# 1577           2          2          14
# 1607           1          2          14
# ...

# %% [markdown]
# ### Gap Analysis: Activities of Dropouts not done by Promoters

# %%
df1_d.loc[df1_d['set1'].isin(set(list(df1_d['set1'].values)) - set(list(df1_new['set1'].values)))].head(10)
# Out:
#                              key                             set1  user_count  \
# 652     e1-c-chigh-e1-c-chigh-e1                    (e1, c-chigh)           1
# 1166   c-alow-e1-c-alow-z1-stop1          (stop1, c-alow, z1, e1)           5
# 1245   v1-c-alow-e1-c-bmed-stop1  (stop1, c-bmed, e1, c-alow, v1)           3
# 1499      v2-e1-break1-v2-break1                 (break1, v2, e1)           1
# 1606   c-bmed-e1-c-bmed-z1-stop1          (stop1, z1, e1, c-bmed)           3
# 1581          e1-v2-e4-break1-v2             (break1, v2, e1, e4)           2
# 1649              v2-e1-v1-e1-s2                 (s2, v2, e1, v1)           2
# 1654  l2-c-bmed-break1-c-bmed-l2             (break1, c-bmed, l2)           2
# 1594      z1-e1-break1-z1-break1                 (break1, z1, e1)           1
# 1723          e1-s2-break1-v3-e1             (s2, v3, break1, e1)           2
#
#       max_count  sum_counts
# 652          14          23
# 1166         10          11
# ...

# %% [markdown]
# ## Promoted 2 vs Dropout 2

# %% [markdown]
# ### Promoted 2 patterns

# %%
df2_new = get_df_set(sax_mtf_p2)
df2_new.loc[df2_new['sum_counts']>np.quantile(df2_new['sum_counts'], 0.9)].head(10)
# Out:
#                                      key                           set1  \
# 0     break1-c-alow-break1-c-alow-break1               (break1, c-alow)
# 2                 l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)
# 10        c-bmed-break1-c-bmed-break1-l1           (break1, c-bmed, l1)
# 44       break1-c-chigh-break1-c-bmed-l1  (l1, break1, c-bmed, c-chigh)
# 86                e1-c-alow-e1-c-bmed-e1           (c-alow, e1, c-bmed)
# 94        c-alow-l1-c-bmed-break1-c-bmed   (break1, c-alow, c-bmed, l1)
# 145  c-bmed-break1-c-chigh-break1-c-bmed      (break1, c-bmed, c-chigh)
# 153               l1-c-bmed-l1-c-bmed-l1                   (l1, c-bmed)
# 163   c-bmed-break1-c-bmed-break1-c-bmed               (break1, c-bmed)
# 155   break1-c-alow-break1-c-bmed-break1       (break1, c-alow, c-bmed)
#
#      user_count  max_count  sum_counts
# 0            44        224         437
# 2            31         59         353
# 10           15         33         299
# ...

# %% [markdown]
# ### Dropout 2 patterns

# %%
df2_d = get_df_set(sax_mtf_d2)
df2_d.loc[df2_d['sum_counts']>np.quantile(df2_d['sum_counts'], 0.9)].head(10)
# Out:
#                                      key                           set1  \
# 0        c-chigh-break1-c-bmed-l1-c-bmed  (l1, break1, c-bmed, c-chigh)
# 39            c-alow-l1-c-bmed-l1-c-bmed           (l1, c-alow, c-bmed)
# 47        c-bmed-l1-c-bmed-break1-c-bmed           (break1, c-bmed, l1)
# 76        c-bmed-l1-c-alow-break1-c-bmed   (l1, c-alow, break1, c-bmed)
# 125   break1-c-bmed-break1-c-alow-break1       (break1, c-alow, c-bmed)
# 133               e1-c-bmed-e1-c-alow-e1           (c-bmed, c-alow, e1)
# 141   c-bmed-break1-c-bmed-break1-c-bmed               (break1, c-bmed)
# 143           c-alow-e1-c-alow-e1-c-alow                   (c-alow, e1)
# 145  c-bmed-break1-c-bmed-break1-c-chigh      (break1, c-bmed, c-chigh)
# 153       break1-c-bmed-break1-c-bmed-v1           (break1, c-bmed, v1)
#
#      user_count  max_count  sum_counts
# 0             5         14         154
# 39            9         24         142
# 47           10         17         140
# ...

# %% [markdown]
# ### Gap analysis: Activities of Promoters not done by Dropouts

# %%
df2_new.loc[df2_new['set1'].isin(set(list(df2_new['set1'].values)) - set(list(df2_d['set1'].values)))].head(10)
# Out:
#                                key                              set1  \
# 1348    c-bmed-v1-c-alow-p1-c-bmed          (p1, c-alow, c-bmed, v1)
# 1333        v1-c-alow-s2-c-alow-s2                  (s2, c-alow, v1)
# 1547        e1-c-alow-s2-c-alow-v1              (s2, c-alow, e1, v1)
# 1575    c-alow-v1-c-alow-v1-c-alow                      (c-alow, v1)
# 1786    e1-c-chigh-break1-l1-stop1  (break1, stop1, l1, e1, c-chigh)
# 1791  c-chigh-e1-c-chigh-break1-l1         (break1, e1, c-chigh, l1)
# 2011  c-alow-l2-c-chigh-l1-c-chigh         (l1, c-alow, c-chigh, l2)
# 2114    c-bmed-l1-c-bmed-p1-c-bmed                  (p1, c-bmed, l1)
# 2130        v1-c-bmed-p1-z1-c-alow      (p1, c-bmed, z1, c-alow, v1)
# 2181        l1-c-bmed-l1-c-alow-v2          (l1, c-alow, v2, c-bmed)
#
#       user_count  max_count  sum_counts
# 1348           1          5          26
# 1333           3          3          26
# 1547           2          2          20
# 1575           6         11          18
# ...

# %% [markdown]
# ### Gap Analysis: Activities of Dropouts not done by Promoters

# %%
df2_d.loc[df2_d['set1'].isin(set(list(df2_d['set1'].values)) - set(list(df2_new['set1'].values)))].head(10)
# Out:
#                                 key                                 set1  \
# 758      break1-p1-break1-p1-break1                         (break1, p1)
# 925   break1-c-bmed-v1-c-alow-stop1  (break1, stop1, c-bmed, c-alow, v1)
# 984      break1-c-bmed-e1-c-bmed-p1             (p1, break1, e1, c-bmed)
# 1044         p1-c-bmed-p1-c-bmed-p1                         (p1, c-bmed)
# 1088         break1-p1-break1-v1-e1                 (break1, p1, e1, v1)
# 1245             s1-break1-v1-e1-s1                 (s1, break1, e1, v1)
# 1305         s1-c-bmed-v1-c-bmed-l1                 (s1, c-bmed, l1, v1)
# 1414             break1-v1-e1-s1-p1             (break1, p1, s1, e1, v1)
# 1334         v1-break1-v1-break1-z1                     (break1, z1, v1)
# 1362         e3-c-alow-e3-c-bmed-l1             (c-bmed, c-alow, e3, l1)
#
#       user_count  max_count  sum_counts
# 758            7          9          18
# 925            4          5          12
# 984            1          3          10
# ...

# %% [markdown]
# ## Promoted 3 vs Dropout 3

# %% [markdown]
# ### Promoted 3 patterns

# %%
df3_new = get_df_set(sax_mtf_p3)
df3_new.loc[df3_new['sum_counts']>np.quantile(df3_new['sum_counts'], 0.9)].head(10)
# Out:
#                                       key                           set1  \
# 0                  e1-c-bmed-e1-c-alow-e1           (c-bmed, c-alow, e1)
# 8     break1-c-chigh-break1-c-bmed-break1      (break1, c-bmed, c-chigh)
# 16                 e1-c-alow-e1-c-alow-e1                   (c-alow, e1)
# 18   break1-c-chigh-break1-c-chigh-break1              (break1, c-chigh)
# 20     break1-c-bmed-break1-c-bmed-break1               (break1, c-bmed)
# 22        l1-c-bmed-break1-c-chigh-break1  (break1, c-bmed, c-chigh, l1)
# 71     break1-c-bmed-break1-c-alow-break1       (break1, c-alow, c-bmed)
# 79         c-bmed-break1-c-bmed-l1-c-bmed           (break1, c-bmed, l1)
# 113                e1-c-bmed-e1-c-bmed-e1                   (c-bmed, e1)
# 115                l1-c-bmed-l1-c-alow-l1           (l1, c-alow, c-bmed)
#
#      user_count  max_count  sum_counts
# 0           104        184         962
# 8            81        139         756
# 16          109        370         646
# ...

# %% [markdown]
# ### Dropout 3 patterns

# %%
df3_d = get_df_set(sax_mtf_d3)
df3_d.loc[df3_d['sum_counts']>np.quantile(df3_d['sum_counts'], 0.9)].head(10)
# Out:
#                                       key                           set1  \
# 0     break1-c-bmed-break1-c-chigh-break1      (break1, c-bmed, c-chigh)
# 8      break1-c-bmed-break1-c-bmed-break1               (break1, c-bmed)
# 10     break1-c-alow-break1-c-bmed-break1       (break1, c-alow, c-bmed)
# 18                 e1-c-alow-e1-c-alow-e1                   (c-alow, e1)
# 20                 e1-c-bmed-e1-c-alow-e1           (c-alow, e1, c-bmed)
# 28         c-bmed-break1-c-bmed-l1-c-bmed           (l1, break1, c-bmed)
# 63        c-bmed-l1-c-bmed-break1-c-chigh  (l1, break1, c-bmed, c-chigh)
# 103        c-bmed-v1-c-bmed-break1-c-bmed           (break1, c-bmed, v1)
# 135            c-alow-l1-c-bmed-l1-c-bmed           (l1, c-alow, c-bmed)
# 143  break1-c-chigh-break1-c-chigh-break1              (break1, c-chigh)
#
#      user_count  max_count  sum_counts
# 0            50         87         530
# 8           104        245         475
# 10           49         78         409
# ...

# %% [markdown]
# ### Gap analysis: Activities of Promoters not done by Dropouts

# %%
df3_new.loc[df3_new['set1'].isin(set(list(df3_new['set1'].values)) - set(list(df3_d['set1'].values)))].head(10)
# Out:
#                                    key                              set1  \
# 1951                    v2-e2-v2-e1-v4                  (v2, e1, e2, v4)
# 2638                    s2-v1-s2-v1-s2                          (s2, v1)
# 2700                    e1-v2-e1-v4-e1                      (v2, e1, v4)
# 3107          l1-c-chigh-l1-c-chigh-l2                 (l1, c-chigh, l2)
# 3183          v1-c-chigh-v1-c-chigh-e2                 (e2, c-chigh, v1)
# 3248  break1-c-chigh-break1-c-chigh-v6             (break1, c-chigh, v6)
# 3557        c-bmed-l1-c-chigh-l2-stop1  (l1, stop1, c-bmed, l2, c-chigh)
# 3423            l3-c-alow-l1-c-alow-v1              (l1, l3, c-alow, v1)
# 3436      v1-c-chigh-break1-c-chigh-l2         (break1, c-chigh, l2, v1)
# 3507        break1-c-bmed-l1-c-bmed-e2          (l1, break1, c-bmed, e2)
#
#       user_count  max_count  sum_counts
# 1951           1          3          24
# 2638           2          7          14
# 2700           4          4          13
# ...

# %% [markdown]
# ### Gap Analysis: Activities of Dropouts not done by Promoters

# %%
df3_d.loc[df3_d['set1'].isin(set(list(df3_d['set1'].values)) - set(list(df3_new['set1'].values)))].head(10)
# Out:
#                                  key                                  set1  \
# 1125      c-alow-l1-c-alow-s2-c-alow                      (l1, s2, c-alow)
# 1168          l1-c-alow-s2-c-alow-e1                  (s2, c-alow, e1, l1)
# 1932          v1-c-alow-s4-l1-c-alow                  (l1, c-alow, s4, v1)
# 1943          e2-v1-c-alow-s2-c-alow                  (s2, c-alow, e2, v1)
# 2049  e1-c-bmed-break1-c-chigh-stop1  (break1, stop1, c-bmed, e1, c-chigh)
# 2016      c-alow-s2-break1-l1-c-alow              (break1, c-alow, s2, l1)
# 2121      c-alow-s2-c-alow-s2-c-alow                          (s2, c-alow)
# 2158          s2-c-alow-s2-v2-c-alow                      (s2, c-alow, v2)
# 2259          e2-v1-e2-c-alow-break1              (break1, c-alow, e2, v1)
# 2278          l1-c-bmed-e1-s2-c-alow          (l1, c-bmed, e1, s2, c-alow)
#
#       user_count  max_count  sum_counts
# 1125           2          6          37
# 1168           1          3          36
# ...

# %% [markdown]
# ## Promoted 4 vs Dropout 4

# %% [markdown]
# ### Promoted 4 patterns

# %%
df4_new = get_df_set(sax_mtf_p4)
df4_new.loc[df4_new['sum_counts']>np.quantile(df4_new['sum_counts'], 0.9)].head(10)
# Out:
#                                       key                           set1  \
# 0     break1-c-chigh-break1-c-bmed-break1      (break1, c-bmed, c-chigh)
# 8      break1-c-bmed-break1-c-bmed-break1               (break1, c-bmed)
# 10   break1-c-chigh-break1-c-chigh-break1              (break1, c-chigh)
# 12         c-bmed-v1-c-bmed-break1-c-bmed           (break1, c-bmed, v1)
# 54     break1-c-bmed-break1-c-alow-break1       (break1, c-alow, c-bmed)
# 62        v1-c-bmed-break1-c-chigh-break1  (break1, c-bmed, c-chigh, v1)
# 122                e1-c-bmed-e1-c-alow-e1           (c-bmed, c-alow, e1)
# 130        c-bmed-l1-c-bmed-break1-c-bmed           (break1, c-bmed, l1)
# 171        c-bmed-v1-c-alow-break1-c-bmed   (break1, c-alow, c-bmed, v1)
# 231                l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)
#
#      user_count  max_count  sum_counts
# 0           274        880        4713
# 8           329       2167        3998
# 10          260       1624        2990
# ...

# %% [markdown]
# ### Dropout 4 patterns

# %%
df4_d = get_df_set(sax_mtf_d4)
df4_d.loc[df4_d['sum_counts']>np.quantile(df4_d['sum_counts'], 0.9)].head(10)
# Out:
#                                       key                           set1  \
# 0     break1-c-chigh-break1-c-bmed-break1      (break1, c-bmed, c-chigh)
# 8      break1-c-bmed-break1-c-bmed-break1               (break1, c-bmed)
# 10   break1-c-chigh-break1-c-chigh-break1              (break1, c-chigh)
# 12     break1-c-alow-break1-c-bmed-break1       (break1, c-alow, c-bmed)
# 20                 e1-c-bmed-e1-c-alow-e1           (c-bmed, c-alow, e1)
# 28         break1-c-bmed-break1-c-bmed-v1           (break1, c-bmed, v1)
# 70                 l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)
# 78         c-bmed-l1-c-bmed-break1-c-bmed           (break1, c-bmed, l1)
# 119        c-bmed-e1-c-bmed-break1-c-bmed           (break1, e1, c-bmed)
# 159       v1-c-bmed-break1-c-chigh-break1  (break1, c-bmed, c-chigh, v1)
#
#      user_count  max_count  sum_counts
# 0           243        707        3694
# 8           301       1813        3325
# 10          223       1182        2165
# ...

# %% [markdown]
# ### Gap analysis: Activities of Promoters not done by Dropouts

# %%
df4_new.loc[df4_new['set1'].isin(set(list(df4_new['set1'].values)) - set(list(df4_d['set1'].values)))].head(10)
# Out:
#                                    key                           set1  \
# 13524                   p1-z1-e1-z1-p2               (p1, z1, p2, e1)
# 14151    c-chigh-v12-e1-c-chigh-break1     (break1, e1, v12, c-chigh)
# 14224              p1-z2-v1-c-chigh-v1          (p1, z2, c-chigh, v1)
# 15036              v1-e1-c-bmed-v10-e1          (e1, c-bmed, v10, v1)
# 15150  break1-c-chigh-e7-c-bmed-break1  (break1, c-bmed, c-chigh, e7)
# 15874      v2-c-bmed-break1-v10-c-bmed      (break1, v2, c-bmed, v10)
# 15766           v1-break1-s2-e3-break1           (break1, s2, e3, v1)
# 16372                   e1-v1-e1-v8-e1                   (v8, e1, v1)
# 16458                   e2-v5-e1-v1-e1               (v5, e1, e2, v1)
# 16975       c-bmed-v1-c-bmed-v6-c-bmed               (c-bmed, v6, v1)
#
#        user_count  max_count  sum_counts
# 13524           1          5           9
# 14151           2          2           8
# 14224           2          2           8
# ...

# %% [markdown]
# ### Gap Analysis: Activities of Dropouts not done by Promoters

# %%
df4_d.loc[df4_d['set1'].isin(set(list(df4_d['set1'].values)) - set(list(df4_new['set1'].values)))].head(10)
# Out:
# Empty DataFrame
# Columns: [key, set1, user_count, max_count, sum_counts]
# Index: []

# %% [markdown]
# # Superusers vs Promoted users

# %% [markdown]
# ## Superusers pattern

# %%
df_super = get_df_set(sax_mtf_p4)
df_super.loc[df_super['sum_counts']>np.quantile(df_super['sum_counts'], 0.9)].head(10)
# Out:
#                                       key                           set1  \
# 0     break1-c-chigh-break1-c-bmed-break1      (break1, c-bmed, c-chigh)
# 8      break1-c-bmed-break1-c-bmed-break1               (break1, c-bmed)
# 10   break1-c-chigh-break1-c-chigh-break1              (break1, c-chigh)
# 12         c-bmed-v1-c-bmed-break1-c-bmed           (break1, c-bmed, v1)
# 54     break1-c-bmed-break1-c-alow-break1       (break1, c-alow, c-bmed)
# 62        v1-c-bmed-break1-c-chigh-break1  (break1, c-bmed, c-chigh, v1)
# 122                e1-c-bmed-e1-c-alow-e1           (c-bmed, c-alow, e1)
# 130        c-bmed-l1-c-bmed-break1-c-bmed           (break1, c-bmed, l1)
# 171        c-bmed-v1-c-alow-break1-c-bmed   (break1, c-alow, c-bmed, v1)
# 231                l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)
#
#      user_count  max_count  sum_counts
# 0           274        880        4713
# 8           329       2167        3998
# 10          260       1624        2990
# ...

# %% [markdown]
# ## Promoted 1 vs Superusers

# %% [markdown]
# ### Promoted 1 patterns

# %%
df1_new = get_df_set(sax_mtf_p1)
df1_new.loc[df1_new['sum_counts']>np.quantile(df1_new['sum_counts'], 0.9)].head(10)
# Out:
#                              key                           set1  user_count  \
# 0         l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)          47
# 8         e1-c-alow-e1-c-alow-e1                   (c-alow, e1)           9
# 10        e1-c-bmed-e1-c-alow-e1           (c-bmed, c-alow, e1)          10
# 18       l1-c-chigh-l1-c-bmed-l1          (l1, c-bmed, c-chigh)          15
# 26        l1-c-bmed-l1-c-bmed-l1                   (l1, c-bmed)          45
# 28   l1-c-bmed-l1-c-chigh-break1  (l1, break1, c-bmed, c-chigh)           8
# 66        l1-c-alow-l1-c-alow-l1                   (l1, c-alow)          44
# 68    l1-c-alow-l1-c-bmed-break1   (l1, c-alow, break1, c-bmed)           7
# 112   l1-c-bmed-l1-c-bmed-break1           (l1, break1, c-bmed)           7
# 141       l1-c-alow-l1-c-bmed-v1       (l1, c-alow, c-bmed, v1)           6
#
#      max_count  sum_counts
# 0          103         571
# 8          172         335
# 10          42         235
# ...

# %% [markdown]
# ### Gap analysis: Activities of Promoters not done by Superusers

# %%
df1_new.loc[df1_new['set1'].isin(set(list(df1_new['set1'].values)) - set(list(df_super['set1'].values)))].head(10)
# Out:
#                               key                               set1  \
# 1885    c-bmed-v1-break1-l2-stop1    (break1, stop1, c-bmed, l2, v1)
# 1899   c-alow-v1-c-chigh-l1-stop1   (l1, stop1, c-chigh, c-alow, v1)
# 1990   c-bmed-l2-c-chigh-l1-stop1   (l1, stop1, c-bmed, l2, c-chigh)
# 2000    c-bmed-p1-break1-l1-stop1    (p1, stop1, break1, l1, c-bmed)
# 2063        l1-c-bmed-z1-l1-stop1            (l1, stop1, z1, c-bmed)
# 2160  c-chigh-v1-c-alow-p1-c-bmed  (p1, c-bmed, c-chigh, c-alow, v1)
# 2169    l1-c-bmed-l3-c-bmed-stop1            (l1, l3, c-bmed, stop1)
# 2589    break1-l1-break1-l1-stop1                (break1, stop1, l1)
# 2405    c-bmed-p1-c-bmed-l1-stop1            (p1, stop1, c-bmed, l1)
# 2339  c-chigh-l1-c-alow-l3-c-alow          (l1, c-alow, l3, c-chigh)
#
#       user_count  max_count  sum_counts
# 1885           3          3          10
# 1899           1          6           9
# 1990           1          5           8
# 2000           2          4           8
# ...

# %% [markdown]
# ### Gap Analysis: Activities of Superusers not done by Promoters

# %%
df1_d.loc[df1_d['set1'].isin(set(list(df_super['set1'].values)) - set(list(df1_new['set1'].values)))].head(10)
# Out:
#                                  key                             set1  \
# 652         e1-c-chigh-e1-c-chigh-e1                    (e1, c-chigh)
# 1245       v1-c-alow-e1-c-bmed-stop1  (stop1, c-bmed, e1, c-alow, v1)
# 1372    c-chigh-break1-c-chigh-v1-z1        (break1, z1, c-chigh, v1)
# 1499          v2-e1-break1-v2-break1                 (break1, v2, e1)
# 1606       c-bmed-e1-c-bmed-z1-stop1          (stop1, z1, e1, c-bmed)
# 1581              e1-v2-e4-break1-v2             (break1, v2, e1, e4)
# 1633  c-alow-break1-c-alow-break1-z1             (break1, c-alow, z1)
# 1649                  v2-e1-v1-e1-s2                 (s2, v2, e1, v1)
# 1654      l2-c-bmed-break1-c-bmed-l2             (break1, c-bmed, l2)
# 1594          z1-e1-break1-z1-break1                 (break1, z1, e1)
#
#       user_count  max_count  sum_counts
# 652            1         14          23
# 1245           3          3          10
# 1372           2          2           8
# ...

# %% [markdown]
# ## Promoted 2 vs Superusers

# %% [markdown]
# ### Promoted 2 patterns

# %%
df2_new = get_df_set(sax_mtf_p2)
df2_new.loc[df2_new['sum_counts']>np.quantile(df2_new['sum_counts'], 0.9)].head(10)
# Out:
#                                      key                           set1  \
# 0     break1-c-alow-break1-c-alow-break1               (break1, c-alow)
# 2                 l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)
# 10        c-bmed-break1-c-bmed-break1-l1           (break1, c-bmed, l1)
# 44       c-bmed-break1-c-chigh-break1-l1  (l1, break1, c-bmed, c-chigh)
# 86                e1-c-alow-e1-c-bmed-e1           (c-alow, e1, c-bmed)
# 94        c-alow-l1-c-bmed-break1-c-bmed   (break1, c-alow, c-bmed, l1)
# 145  c-bmed-break1-c-chigh-break1-c-bmed      (break1, c-bmed, c-chigh)
# 153       c-bmed-v1-c-bmed-break1-c-bmed           (break1, c-bmed, v1)
# 188   c-bmed-break1-c-bmed-break1-c-bmed               (break1, c-bmed)
# 190               l1-c-bmed-l1-c-bmed-l1                   (l1, c-bmed)
#
#      user_count  max_count  sum_counts
# 0            48        223         436
# 2            32         55         329
# 10           15         33         290
# ...

# %% [markdown]
# ### Gap analysis: Activities of Promoters not done by Superusers

# %%
df2_new.loc[df2_new['set1'].isin(set(list(df2_new['set1'].values)) - set(list(df_super['set1'].values)))].head(10)
# Out:
#                               key                              set1  \
# 1725   e1-c-chigh-break1-l1-stop1  (break1, stop1, l1, e1, c-chigh)
# 1987   c-chigh-l2-c-bmed-l1-stop1  (l1, stop1, c-bmed, l2, c-chigh)
# 2863    c-bmed-p1-c-bmed-l1-stop1           (l1, stop1, p1, c-bmed)
# 2859   l1-c-chigh-break1-l2-stop1  (break1, stop1, l1, l2, c-chigh)
# 2725       l4-c-alow-s2-c-alow-s4              (s2, c-alow, s4, l4)
# 2765   c-alow-e1-c-bmed-z5-c-alow          (z5, c-alow, e1, c-bmed)
# 3176  c-chigh-l1-c-chigh-l2-stop1          (l1, stop1, c-chigh, l2)
# 2952  v11-break1-c-alow-s2-c-alow         (break1, c-alow, s2, v11)
# 2962       s2-c-alow-s2-l2-c-alow                  (s2, c-alow, l2)
# 3030           p1-e2-v1-c-alow-p1              (p1, c-alow, e2, v1)
#
#       user_count  max_count  sum_counts
# 1725           4          9          14
# 1987           2          4          10
# 2863           2          3           5
# 2859           2          2           5
# ...

# %% [markdown]
# ### Gap Analysis: Activities of Superusers not done by Promoters

# %%
df2_d.loc[df2_d['set1'].isin(set(list(df_super['set1'].values)) - set(list(df2_new['set1'].values)))].head(10)
# Out:
#                                 key                                 set1  \
# 758      break1-p1-break1-p1-break1                         (break1, p1)
# 925   break1-c-bmed-v1-c-alow-stop1  (break1, stop1, c-bmed, c-alow, v1)
# 984      break1-c-bmed-e1-c-bmed-p1             (p1, break1, e1, c-bmed)
# 1044         p1-c-bmed-p1-c-bmed-p1                         (p1, c-bmed)
# 1088         break1-p1-break1-v1-e1                 (break1, p1, e1, v1)
# 1245             s1-break1-v1-e1-s1                 (s1, break1, e1, v1)
# 1305         s1-c-bmed-v1-c-bmed-l1                 (s1, c-bmed, l1, v1)
# 1414             break1-v1-e1-s1-p1             (break1, p1, s1, e1, v1)
# 1334         v1-break1-v1-break1-z1                     (break1, z1, v1)
# 1362         e3-c-alow-e3-c-bmed-l1             (c-bmed, c-alow, e3, l1)
#
#       user_count  max_count  sum_counts
# 758            7          9          18
# 925            4          5          12
# 984            1          3          10
# ...

# %% [markdown]
# ## Promoted 3 vs Superusers

# %% [markdown]
# ### Promoted 3 patterns

# %%
df3_new = get_df_set(sax_mtf_p3)
df3_new.loc[df3_new['sum_counts']>np.quantile(df3_new['sum_counts'], 0.9)].head(10)
# Out:
#                                       key                           set1  \
# 0                  e1-c-bmed-e1-c-alow-e1           (c-bmed, c-alow, e1)
# 8     break1-c-chigh-break1-c-bmed-break1      (break1, c-bmed, c-chigh)
# 16                 e1-c-alow-e1-c-alow-e1                   (c-alow, e1)
# 18     break1-c-bmed-break1-c-bmed-break1               (break1, c-bmed)
# 20   break1-c-chigh-break1-c-chigh-break1              (break1, c-chigh)
# 22        l1-c-bmed-break1-c-chigh-break1  (break1, c-bmed, c-chigh, l1)
# 71     break1-c-bmed-break1-c-alow-break1       (break1, c-alow, c-bmed)
# 79         c-bmed-break1-c-bmed-l1-c-bmed           (break1, c-bmed, l1)
# 113                e1-c-bmed-e1-c-bmed-e1                   (c-bmed, e1)
# 115                l1-c-bmed-l1-c-alow-l1           (l1, c-alow, c-bmed)
#
#      user_count  max_count  sum_counts
# 0            92        180         944
# 8            83        137         723
# 16          107        369         645
# ...

# %% [markdown]
# ### Gap analysis: Activities of Promoters not done by Superusers

# %%
df3_new.loc[df3_new['set1'].isin(set(list(df3_new['set1'].values)) - set(list(df_super['set1'].values)))].head(10)
# Out:
#                                  key                                  set1  \
# 2544                  s2-v1-s2-v1-s2                              (s2, v1)
# 3288      c-bmed-l1-c-chigh-l2-stop1      (l1, stop1, c-bmed, l2, c-chigh)
# 3486      l1-c-chigh-break1-l2-stop1      (l1, stop1, break1, l2, c-chigh)
# 3528       v1-c-bmed-break1-l2-stop1       (break1, stop1, c-bmed, l2, v1)
# 4065      e1-c-chigh-break1-l1-stop1      (break1, stop1, l1, e1, c-chigh)
# 4157      c-bmed-l1-c-chigh-l3-stop1      (l1, stop1, c-bmed, l3, c-chigh)
# 4200  c-chigh-break1-c-bmed-l3-stop1  (break1, stop1, c-bmed, l3, c-chigh)
# 4054      c-chigh-v1-c-alow-l1-stop1      (l1, stop1, c-chigh, c-alow, v1)
# 4071      c-alow-e6-c-bmed-e1-c-alow              (c-alow, e1, c-bmed, e6)
# 3930    z1-v5-c-chigh-break1-c-chigh             (break1, v5, z1, c-chigh)
#
#       user_count  max_count  sum_counts
# 2544           3          7          14
# 3288           3          4           8
# ...

# %% [markdown]
# ### Gap Analysis: Activities of Superusers not done by Promoters

# %%
df3_d.loc[df3_d['set1'].isin(set(list(df_super['set1'].values)) - set(list(df3_new['set1'].values)))].head(10)
# Out:
#                                  key                                  set1  \
# 1125      c-alow-l1-c-alow-s2-c-alow                      (l1, s2, c-alow)
# 1168          l1-c-alow-s2-c-alow-e1                  (s2, c-alow, e1, l1)
# 1932          v1-c-alow-s4-l1-c-alow                  (l1, c-alow, s4, v1)
# 1943          e2-v1-c-alow-s2-c-alow                  (s2, c-alow, e2, v1)
# 2049  e1-c-bmed-break1-c-chigh-stop1  (break1, stop1, c-bmed, e1, c-chigh)
# 2016      c-alow-s2-break1-l1-c-alow              (break1, c-alow, s2, l1)
# 2070                  v1-e1-v1-e1-v1                              (e1, v1)
# 2158          s2-c-alow-s2-v2-c-alow                      (s2, c-alow, v2)
# 2259          e2-v1-e2-c-alow-break1              (break1, c-alow, e2, v1)
# 2278          l1-c-bmed-e1-s2-c-alow          (l1, c-bmed, e1, s2, c-alow)
#
#       user_count  max_count  sum_counts
# 1125           2          6          37
# 1168           1          3          36
# ...

# %% [markdown]
# # Superusers vs Other Users

# %% [markdown]
# ## Superuser 1 vs Other 1

# %% [markdown]
# ### Superuser 1 patterns

# %%
df1_new = get_df_set(sax_mtf_p1)
df1_new.loc[df1_new['sum_counts']>np.quantile(df1_new['sum_counts'], 0.9)].head(10)
# Out:
#                                       key                              set1  \
# 0         l1-break1-c-chigh-break1-c-bmed     (l1, break1, c-bmed, c-chigh)
# 10                l1-c-bmed-v1-c-chigh-l1         (l1, c-bmed, c-chigh, v1)
# 18         l1-c-bmed-break1-c-bmed-break1              (l1, break1, c-bmed)
# 36  c-chigh-break1-c-chigh-break1-c-chigh                 (break1, c-chigh)
# 25           c-chigh-l1-c-chigh-l1-c-bmed             (l1, c-bmed, c-chigh)
# 30             l1-c-alow-l1-c-bmed-break1      (break1, c-alow, c-bmed, l1)
# 48             c-bmed-e1-c-bmed-e1-c-bmed                      (e1, c-bmed)
# 38             v1-c-bmed-v1-c-bmed-break1              (break1, c-bmed, v1)
# 43             l1-c-alow-l2-break1-c-bmed  (l1, break1, c-bmed, l2, c-alow)
# 50           c-chigh-z1-break1-c-chigh-v1         (break1, z1, c-chigh, v1)
#
#     user_count  max_count  sum_counts
# 0            1          1          10
# 10           1          1           8
# ...

# %% [markdown]
# ### Other 1 patterns

# %%
df1_d = get_df_set(sax_mtf_d1)
df1_d.loc[df1_d['sum_counts']>np.quantile(df1_d['sum_counts'], 0.9)].head(10)
# Out:
#                              key                           set1  user_count  \
# 0     c-alow-e1-c-alow-e1-c-alow                   (c-alow, e1)          93
# 2         l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)          59
# 18        e1-c-bmed-e1-c-alow-e1           (c-bmed, e1, c-alow)          26
# 10       l1-c-bmed-l1-c-chigh-l1          (l1, c-bmed, c-chigh)          24
# 26        l1-c-bmed-l1-c-bmed-l1                   (l1, c-bmed)          60
# 28   l1-c-bmed-l1-c-chigh-break1  (l1, break1, c-bmed, c-chigh)          10
# 72        l1-c-alow-l1-c-bmed-v1       (l1, c-alow, c-bmed, v1)          10
# 122       l1-c-alow-l1-c-alow-l1                   (l1, c-alow)          58
# 124   l1-c-alow-l1-c-bmed-break1   (l1, c-alow, break1, c-bmed)           7
# 175   l1-c-bmed-l1-c-bmed-break1           (l1, break1, c-bmed)           9
#
#      max_count  sum_counts
# 0          455         901
# 2          145         830
# 18          61         349
# ...

# %% [markdown]
# ### Gap analysis: Activities of Superusers not done by Others

# %%
df1_new.loc[df1_new['set1'].isin(set(list(df1_new['set1'].values)) - set(list(df1_d['set1'].values)))].head(10)
# Out:
#                                  key                               set1  \
# 99               e2-v1-z3-v1-c-chigh              (z3, e2, c-chigh, v1)
# 110      z1-c-chigh-p1-break1-c-alow  (break1, p1, z1, c-chigh, c-alow)
# 119          l1-c-chigh-l1-s2-c-bmed          (l1, s2, c-bmed, c-chigh)
# 127           e1-v2-break1-s9-c-bmed       (break1, c-bmed, e1, v2, s9)
# 129          e1-c-chigh-p1-c-alow-e1          (p1, c-alow, e1, c-chigh)
# 131           break1-v6-e1-v2-c-bmed       (break1, c-bmed, v6, e1, v2)
# 144  p1-break1-c-alow-break1-c-chigh      (p1, c-alow, break1, c-chigh)
# 154           v3-c-alow-v1-z1-c-alow               (c-alow, z1, v3, v1)
# 158               l1-c-bmed-z1-p2-v7           (l1, c-bmed, z1, v7, p2)
# 188           p1-c-bmed-s1-break1-s1           (p1, break1, s1, c-bmed)
#
#      user_count  max_count  sum_counts
# 99            1          1           3
# 110           1          1           3
# 119           1          1           3
# ...

# %% [markdown]
# ### Gap Analysis: Activities of Others not done by Superusers

# %%
df1_d.loc[df1_d['set1'].isin(set(list(df1_d['set1'].values)) - set(list(df1_new['set1'].values)))].head(10)
# Out:
#                                     key                                 set1  \
# 0            c-alow-e1-c-alow-e1-c-alow                         (c-alow, e1)
# 72               l1-c-alow-l1-c-bmed-v1             (l1, c-alow, c-bmed, v1)
# 397  c-bmed-break1-c-bmed-break1-c-alow             (break1, c-alow, c-bmed)
# 450          c-alow-l1-c-alow-v1-c-alow                     (l1, c-alow, v1)
# 502             e1-c-chigh-e1-c-bmed-e1                (c-bmed, e1, c-chigh)
# 609          c-bmed-l2-c-bmed-l1-c-bmed                     (l1, c-bmed, l2)
# 617          c-bmed-l1-c-bmed-break1-v1             (l1, break1, c-bmed, v1)
# 722          c-alow-e2-c-alow-e1-c-alow                     (c-alow, e1, e2)
# 851          c-alow-v1-c-bmed-v1-c-bmed                 (c-alow, c-bmed, v1)
# 967       c-bmed-break1-c-alow-l1-stop1  (l1, break1, stop1, c-bmed, c-alow)
#
#      user_count  max_count  sum_counts
# 0            93        455         901
# 72           10         19         270
# ...

# %% [markdown]
# ## Superusers 2 vs Other 2

# %% [markdown]
# ### Superusers 2 patterns

# %%
df2_new = get_df_set(sax_mtf_p2)
df2_new.loc[df2_new['sum_counts']>np.quantile(df2_new['sum_counts'], 0.9)].head(10)
# Out:
#                                    key                           set1  \
# 0           c-alow-l1-c-bmed-l1-c-bmed           (l1, c-alow, c-bmed)
# 7               l1-c-bmed-l1-c-bmed-l1                   (l1, c-bmed)
# 9       c-bmed-l1-c-alow-break1-c-bmed   (l1, c-alow, break1, c-bmed)
# 19          c-bmed-l1-c-alow-e1-c-bmed       (c-bmed, c-alow, e1, l1)
# 27      break1-c-bmed-break1-c-bmed-l1           (l1, break1, c-bmed)
# 36  c-bmed-break1-c-alow-break1-c-bmed       (break1, c-alow, c-bmed)
# 43     c-bmed-break1-c-bmed-v1-c-chigh  (break1, c-bmed, c-chigh, v1)
# 51          c-bmed-l2-c-bmed-l1-c-bmed               (l1, c-bmed, l2)
# 56        c-chigh-v1-c-bmed-v1-c-chigh          (c-bmed, c-chigh, v1)
# 70          c-bmed-v1-c-bmed-v1-c-bmed                   (c-bmed, v1)
#
#     user_count  max_count  sum_counts
# 0            2          6          24
# 7            1         11          18
# 9            2          2          13
# 19           3          3          12
# ...

# %% [markdown]
# ### Other 2 patterns

# %%
df2_d = get_df_set(sax_mtf_d2)
df2_d.loc[df2_d['sum_counts']>np.quantile(df2_d['sum_counts'], 0.9)].head(10)
# Out:
#                                      key                           set1  \
# 0     break1-c-alow-break1-c-alow-break1               (break1, c-alow)
# 2                 l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)
# 10       c-chigh-break1-c-bmed-l1-c-bmed  (l1, break1, c-bmed, c-chigh)
# 59        c-bmed-break1-c-bmed-l1-c-bmed           (break1, c-bmed, l1)
# 96                e1-c-bmed-e1-c-alow-e1           (c-alow, e1, c-bmed)
# 104       c-alow-l1-c-bmed-break1-c-bmed   (break1, c-alow, c-bmed, l1)
# 160  c-bmed-break1-c-chigh-break1-c-bmed      (break1, c-bmed, c-chigh)
# 168   c-bmed-break1-c-bmed-break1-c-bmed               (break1, c-bmed)
# 170   break1-c-alow-break1-c-bmed-break1       (break1, c-alow, c-bmed)
# 178       c-bmed-v1-c-bmed-break1-c-bmed           (break1, c-bmed, v1)
#
#      user_count  max_count  sum_counts
# 0            85        243         471
# 2            39         75         447
# 10           14         22         432
# ...

# %% [markdown]
# ### Gap analysis: Activities of Superusers not done by Others

# %%
df2_new.loc[df2_new['set1'].isin(set(list(df2_new['set1'].values)) - set(list(df2_d['set1'].values)))].head(10)
# Out:
#                          key                           set1  user_count  \
# 189     e21-break1-e86-p1-v4     (break1, p1, e86, v4, e21)           1
# 195          e86-p1-v4-s4-e1          (p1, s4, e86, e1, v4)           1
# 196   e3-c-bmed-s4-c-bmed-l1           (l1, c-bmed, s4, e3)           1
# 198      c-chigh-v1-z1-v5-e3      (v5, z1, c-chigh, e3, v1)           1
# 199  e1-c-bmed-e1-c-chigh-z1      (c-bmed, z1, e1, c-chigh)           1
# 200       e1-c-bmed-v2-e1-v5           (v5, c-bmed, v2, e1)           1
# 201  e1-v3-c-chigh-v2-break1  (break1, e1, v3, c-chigh, v2)           1
# 203    e13-v1-e21-break1-e86    (break1, e86, e21, e13, v1)           1
# 204  c-chigh-v1-c-bmed-v5-s1  (c-bmed, s1, v5, c-chigh, v1)           1
# 207  e1-c-chigh-z1-c-alow-l1  (l1, z1, e1, c-chigh, c-alow)           1
#
#      max_count  sum_counts
# 189          1           1
# 195          1           1
# 196          1           1
# 198          1           1
# 199          1           1
# ...

# %% [markdown]
# ### Gap Analysis: Activities of Other not done by Superusers

# %%
df2_d.loc[df2_d['set1'].isin(set(list(df2_d['set1'].values)) - set(list(df2_new['set1'].values)))].head(10)
# Out:
#                                 key                              set1  \
# 259          e1-c-alow-e1-c-alow-e1                      (c-alow, e1)
# 477      c-alow-l2-c-bmed-l1-c-bmed          (l1, c-alow, c-bmed, l2)
# 562          e1-c-bmed-e1-c-bmed-l1                  (l1, e1, c-bmed)
# 589      c-bmed-v1-c-bmed-v1-c-alow              (c-alow, c-bmed, v1)
# 702          l1-c-alow-l1-c-alow-v1                  (l1, c-alow, v1)
# 803  c-bmed-break1-c-bmed-e1-c-bmed              (break1, e1, c-bmed)
# 819     c-chigh-e1-c-bmed-l1-c-bmed         (l1, e1, c-bmed, c-chigh)
# 851  break1-c-alow-l1-c-alow-break1              (break1, c-alow, l1)
# 899      c-chigh-l1-c-bmed-l1-stop1      (l1, stop1, c-bmed, c-chigh)
# 934      break1-c-bmed-l1-c-alow-v1  (l1, break1, c-bmed, c-alow, v1)
#
#      user_count  max_count  sum_counts
# 259          32        114         211
# 477          12         14         141
# 562           8         17         117
# ...

# %% [markdown]
# ## Superusers 3 vs Others 3

# %% [markdown]
# ### Superusers 3 patterns

# %%
df3_new = get_df_set(sax_mtf_p3)
df3_new.loc[df3_new['sum_counts']>np.quantile(df3_new['sum_counts'], 0.9)].head(10)
# Out:
#                                       key                           set1  \
# 0   c-chigh-break1-c-chigh-break1-c-chigh              (break1, c-chigh)
# 2    c-bmed-break1-c-chigh-break1-c-chigh      (break1, c-bmed, c-chigh)
# 10        break1-c-chigh-break1-c-bmed-v1  (break1, c-bmed, c-chigh, v1)
# 28             c-bmed-l1-c-bmed-l1-c-bmed                   (l1, c-bmed)
# 30       c-bmed-l1-c-chigh-break1-c-chigh  (l1, break1, c-bmed, c-chigh)
# 57             c-bmed-e1-c-bmed-e1-c-bmed                   (e1, c-bmed)
# 47         c-bmed-e1-c-bmed-break1-c-bmed           (break1, e1, c-bmed)
# 59             break1-c-bmed-v1-c-bmed-v1           (break1, c-bmed, v1)
# 67           c-bmed-v1-c-chigh-v1-c-chigh          (c-bmed, c-chigh, v1)
# 75                 e1-c-bmed-e1-c-alow-e1           (c-alow, e1, c-bmed)
#
#     user_count  max_count  sum_counts
# 0            7         19          35
# 2            8          8          33
# 10           3          3          32
# ...

# %% [markdown]
# ### Other 3 patterns

# %%
df3_d = get_df_set(sax_mtf_d3)
df3_d.loc[df3_d['sum_counts']>np.quantile(df3_d['sum_counts'], 0.9)].head(10)
# Out:
#                                       key                           set1  \
# 0                  e1-c-bmed-e1-c-alow-e1           (c-alow, e1, c-bmed)
# 8     break1-c-chigh-break1-c-bmed-break1      (break1, c-bmed, c-chigh)
# 16                 e1-c-alow-e1-c-alow-e1                   (c-alow, e1)
# 18     break1-c-bmed-break1-c-bmed-break1               (break1, c-bmed)
# 20     break1-c-bmed-break1-c-alow-break1       (break1, c-alow, c-bmed)
# 28   break1-c-chigh-break1-c-chigh-break1              (break1, c-chigh)
# 30        c-bmed-l1-c-bmed-break1-c-chigh  (l1, break1, c-bmed, c-chigh)
# 83         c-bmed-break1-c-bmed-l1-c-bmed           (l1, break1, c-bmed)
# 122                e1-c-bmed-e1-c-bmed-e1                   (c-bmed, e1)
# 124                l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)
#
#      user_count  max_count  sum_counts
# 0           113        230        1224
# 8           143        220        1220
# 16          147        576        1051
# ...

# %% [markdown]
# ### Gap analysis: Activities of SUperusers not done by Other

# %%
df3_new.loc[df3_new['set1'].isin(set(list(df3_new['set1'].values)) - set(list(df3_d['set1'].values)))].head(10)
# Out:
#                         key                      set1  user_count  max_count  \
# 283          e2-z1-e2-z1-e2                  (z1, e2)           1          2
# 296          z3-e3-z1-e2-z1          (z3, z1, e3, e2)           1          1
# 322          e4-z2-e2-z1-e2          (e4, z2, z1, e2)           1          1
# 326      v3-s4-e1-break1-e1      (break1, v3, s4, e1)           1          1
# 339          s2-e2-s8-v1-z1      (e2, z1, s2, s8, v1)           1          1
# 351      s1-e2-s2-e1-break1  (break1, e2, s1, e1, s2)           1          1
# 354          s1-e1-s3-e1-s1              (s1, s3, e1)           1          1
# 377  s2-break1-v1-break1-z1      (break1, s2, z1, v1)           1          1
# 380          s4-v1-e1-v1-e1              (s4, e1, v1)           1          1
# 400  z1-break1-s2-break1-e1      (break1, s2, z1, e1)           1          1
#
#      sum_counts
# 283           4
# 296           4
# 322           4
# 326           4
# 339           3
# 351           3
# ...

# %% [markdown]
# ### Gap Analysis: Activities of Other not done by Superusers

# %%
df3_d.loc[df3_d['set1'].isin(set(list(df3_d['set1'].values)) - set(list(df3_new['set1'].values)))].head(10)
# Out:
#                                      key                              set1  \
# 834   break1-c-alow-break1-c-alow-break1                  (break1, c-alow)
# 963           c-alow-l1-c-alow-v1-c-alow                  (l1, c-alow, v1)
# 1285              l1-c-alow-l1-c-alow-l1                      (l1, c-alow)
# 1601   break1-c-bmed-break1-c-bmed-stop1           (break1, stop1, c-bmed)
# 1602              c-bmed-l1-c-alow-v1-e1      (l1, c-bmed, e1, c-alow, v1)
# 1761         e1-c-chigh-break1-c-alow-e1     (break1, c-alow, e1, c-chigh)
# 1796          break1-c-bmed-l1-c-alow-e1  (break1, l1, c-bmed, e1, c-alow)
# 1827              l1-c-alow-v1-c-alow-e1              (l1, c-alow, e1, v1)
# 1908              v1-c-alow-s2-l1-c-alow              (s2, c-alow, l1, v1)
# 1959              c-alow-s2-c-alow-v1-s2                  (s2, c-alow, v1)
#
#       user_count  max_count  sum_counts
# 834           61        135         215
# 963           12         19         154
# ...

# %% [markdown]
# ## Superusers 4 vs Other 4

# %% [markdown]
# ### Superuser 4 patterns

# %%
df4_new = get_df_set(sax_mtf_p4)
df4_new.loc[df4_new['sum_counts']>np.quantile(df4_new['sum_counts'], 0.9)].head(10)
# Out:
#                                       key                           set1  \
# 0     break1-c-chigh-break1-c-bmed-break1      (break1, c-bmed, c-chigh)
# 8         c-bmed-v1-c-bmed-break1-c-chigh  (break1, c-bmed, c-chigh, v1)
# 67   break1-c-chigh-break1-c-chigh-break1              (break1, c-chigh)
# 69         c-bmed-break1-c-bmed-v1-c-bmed           (break1, c-bmed, v1)
# 106    break1-c-bmed-break1-c-bmed-break1               (break1, c-bmed)
# 108      break1-c-chigh-break1-c-chigh-v1          (break1, c-chigh, v1)
# 145        c-bmed-v1-c-bmed-break1-c-alow   (break1, c-alow, c-bmed, v1)
# 194               v1-c-chigh-v1-c-bmed-v1          (c-bmed, c-chigh, v1)
# 202            c-bmed-v1-c-bmed-v1-c-bmed                   (c-bmed, v1)
# 204            c-bmed-v1-c-bmed-v1-c-alow           (c-alow, c-bmed, v1)
#
#      user_count  max_count  sum_counts
# 0            33        173        1019
# 8            16         52         928
# 67           32        442         825
# ...

# %% [markdown]
# ### Other 4 patterns

# %%
df4_d = get_df_set(sax_mtf_d4)
df4_d.loc[df4_d['sum_counts']>np.quantile(df4_d['sum_counts'], 0.9)].head(10)
# Out:
#                                       key                           set1  \
# 0     break1-c-chigh-break1-c-bmed-break1      (break1, c-bmed, c-chigh)
# 8      break1-c-bmed-break1-c-bmed-break1               (break1, c-bmed)
# 10   break1-c-chigh-break1-c-chigh-break1              (break1, c-chigh)
# 12     break1-c-alow-break1-c-bmed-break1       (break1, c-alow, c-bmed)
# 20                 e1-c-bmed-e1-c-alow-e1           (c-bmed, c-alow, e1)
# 28         break1-c-bmed-break1-c-bmed-v1           (break1, c-bmed, v1)
# 70                 l1-c-alow-l1-c-bmed-l1           (l1, c-alow, c-bmed)
# 78         c-bmed-l1-c-bmed-break1-c-bmed           (break1, c-bmed, l1)
# 119        c-bmed-e1-c-bmed-break1-c-bmed           (break1, e1, c-bmed)
# 159       v1-c-bmed-break1-c-chigh-break1  (break1, c-bmed, c-chigh, v1)
#
#      user_count  max_count  sum_counts
# 0           243        707        3694
# 8           301       1813        3325
# 10          223       1182        2165
# ...

# %% [markdown]
# ### Gap analysis: Activities of Superusers not done by Other

# %%
df4_new.loc[df4_new['set1'].isin(set(list(df4_new['set1'].values)) - set(list(df4_d['set1'].values)))].head(10)
# Out:
#                                   key                           set1  \
# 3492                   p1-z1-e1-z1-p2               (p1, z1, p2, e1)
# 3627              p1-z2-v1-c-chigh-v1          (p1, z2, c-chigh, v1)
# 3697    c-chigh-v12-e1-c-chigh-break1     (break1, e1, v12, c-chigh)
# 3944  e7-break1-c-chigh-break1-c-bmed  (break1, c-bmed, e7, c-chigh)
# 4013          v1-c-bmed-e1-c-bmed-v10          (e1, c-bmed, v10, v1)
# 4178      v2-c-bmed-break1-v10-c-bmed      (break1, v2, c-bmed, v10)
# 4104           v1-break1-s2-e3-break1           (break1, s2, e3, v1)
# 4419                   e2-v5-e1-v1-e1               (v5, e1, e2, v1)
# 4711       c-bmed-v1-c-bmed-v6-c-bmed               (c-bmed, v6, v1)
# 4760                   e1-v1-e1-v8-e1                   (v8, e1, v1)
#
#       user_count  max_count  sum_counts
# 3492           1          5           9
# 3627           2          2           8
# 3697           1          2           8
# 3944           1          1           7
# ...

# %% [markdown]
# ### Gap Analysis: Activities of other not done by Superusers

# %%
df4_d.loc[df4_d['set1'].isin(set(list(df4_d['set1'].values)) - set(list(df4_new['set1'].values)))].head(10)
# Out:
#                                      key                              set1  \
# 2083   break1-c-bmed-break1-c-bmed-stop1           (break1, stop1, c-bmed)
# 2562  break1-c-chigh-break1-c-bmed-stop1  (break1, stop1, c-bmed, c-chigh)
# 3045   break1-c-bmed-break1-c-alow-stop1   (break1, c-alow, c-bmed, stop1)
# 3657          break1-l2-c-alow-l1-c-alow          (break1, c-alow, l2, l1)
# 3931        c-alow-l1-c-chigh-l1-c-chigh             (l1, c-alow, c-chigh)
# 4447         c-bmed-l2-c-bmed-l1-c-chigh         (l1, c-bmed, c-chigh, l2)
# 5206       break1-c-bmed-v1-c-bmed-stop1       (break1, stop1, c-bmed, v1)
# 5599          c-bmed-e1-c-alow-s1-c-bmed          (s1, c-alow, e1, c-bmed)
# 6044           l1-c-alow-l1-c-bmed-stop1       (l1, c-alow, c-bmed, stop1)
# 6102       break1-c-bmed-e1-c-bmed-stop1       (break1, c-bmed, e1, stop1)
#
#       user_count  max_count  sum_counts
# 2083          98        120         120
# 2562          43         51          89
# ...
